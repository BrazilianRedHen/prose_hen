# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
pd.set_option('display.max_rows',None)

# %%
list_head
# Out:
#                   index  PRED
# 0  Processing_materials    20

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                                    index  PRED
# 0                                    Age   185
# 1                                   Goal   138
# 2                              Aggregate    77
# 3                           Taking_sides    54
# 4                                 Degree    43
# 5             Change_position_on_a_scale    39
# 6                   Temporal_collocation    35
# 7                       Ingest_substance    34
# 8                                  Gizmo    30
# 9                        Being_in_effect    27
# 10                                 Means    26
# 11                    Medical_conditions    26
# 12                            Possession    25
# 13                       Quantified_mass    25
# 14                             Increment    24
# 15                        Measure_volume    21
# 16                               Placing    20
# 17                              Creating    19
# 18                      Being_in_control    19
# 19                           Progression    19
# 20                              Evidence    18
# 21                            Importance    17
# 22                    Being_in_operation    17
# 23                 Proportional_quantity    17
# 24                     Locative_relation    16
# 25                              Exchange    15
# 26                                  Food    15
# 27                           Contingency    14
# 28                         Accompaniment    14
# 29                                Giving    13
# 30                           Possibility    12
# 31   Cause_change_of_position_on_a_scale    12
# 32                     Political_locales    12
# 33                              Negation    12
# 34                        Coming_up_with    11
# 35                                Custom    11
# 36                   Earnings_and_losses    11
# 37                               Verdict    10
# 38                                  Rite    10
# 39                               Weather    10
# 40                           Agriculture    10
# 41                       Cause_expansion    10
# 42                             Statement    10
# 43                                Fields     9
# 44                            Capability     9
# 45                       Performing_arts     9
# 46                        Required_event     9
# 47                    People_by_vocation     9
# 48                   Objective_influence     8
# 49                     Intentionally_act     8
# 50                      Cardinal_numbers     8
# 51                              Scrutiny     8
# 52                             Causation     8
# 53                            Assistance     8
# 54                Criminal_investigation     8
# 55                      Measure_duration     8
# 56                           Time_vector     8
# 57                             Frequency     7
# 58                   Commutative_process     7
# 59                               Needing     7
# 60                                Supply     6
# 61           Prevent_or_allow_possession     6
# 62                             Substance     6
# 63                                Weapon     5
# 64                              Instance     5
# 65                         Being_at_risk     5
# 66                         Locale_by_use     5
# 67                               Control     5
# 68                                 Topic     5
# 69                Agree_or_refuse_to_act     5
# 70                Undergo_transformation     5
# 71                      Natural_features     5
# 72                    Part_orientational     5
# 73                      Point_of_dispute     5
# 74                 Commutative_statement     5
# 75                           Self_motion     5
# 76                             Awareness     4
# 77                              Labeling     4
# 78                            Concessive     4
# 79                  Processing_materials     4
# 80                         Extreme_value     4
# 81                       Being_necessary     4
# 82                            Stinginess     4
# 83                 Measurable_attributes     4
# 84                          Identicality     4
# 85                     Speed_description     4
# 86                        Categorization     4
# 87                         Sole_instance     4
# 88                          Cause_change     4
# 89                          Social_event     3
# 90                             Assessing     3
# 91                           Suitability     3
# 92                              Adducing     3
# 93                            Body_parts     3
# 94                               Economy     3
# 95                               Filling     3
# 96                            Likelihood     3
# 97                           Carry_goods     3
# 98                               Kinship     3
# 99                     Cause_to_perceive     3
# 100                            Documents     3
# 101                 Explaining_the_facts     3
# 102                    Behind_the_scenes     3
# 103                            Surviving     3
# 104                                Event     3
# 105                        Expensiveness     3
# 106                       Accomplishment     3
# 107                Perception_experience     3
# 108                  Cause_to_amalgamate     3
# 109                                 Size     3
# 110                  Social_desirability     3
# 111                            Dispersal     3
# 112                             Response     3
# 113                           Satisfying     2
# 114                      Risky_situation     2
# 115                       Becoming_aware     2
# 116                            Diversity     2
# 117                    Coming_to_believe     2
# 118                              Storing     2
# 119                       Being_relevant     2
# 120                             Presence     2
# 121                          Catastrophe     2
# 122                  Have_as_requirement     2
# 123                           Limitation     2
# 124                           Conquering     2
# 125                 Performers_and_roles     2
# 126          Foreign_or_domestic_country     2
# 127                            Sensation     2
# 128                           Businesses     2
# 129           Continued_state_of_affairs     2
# 130                       Food_gathering     2
# 131                            Buildings     2
# 132                      Desirable_event     2
# 133                             Choosing     2
# 134                        Dead_or_alive     2
# 135                         Be_subset_of     2
# 136                       Precariousness     2
# 137                         Cause_motion     2
# 138                       Undergo_change     2
# 139            Body_description_holistic     2
# 140                      Distinctiveness     2
# 141                             Boundary     2
# 142                      Experimentation     2
# 143                           Commitment     2
# 144                          Obviousness     2
# 145                            Certainty     2
# 146                   Terms_of_agreement     2
# 147                             Dynamism     2
# 148                               Aiming     2
# 149                        Collaboration     2
# 150                            Dimension     2
# 151                          Intoxicants     2
# 152                    Duration_relation     2
# 153                           Path_shape     2
# 154                          Temperature     2
# 155           Condition_symptom_relation     2
# 156                             Research     2
# 157            Level_of_force_resistance     2
# 158                 Attitude_description     2
# 159               Improvement_or_decline     2
# 160                    Experiencer_focus     2
# 161                            Attention     1
# 162                 Distributed_position     1
# 163                                Color     1
# 164                  Operational_testing     1
# 165                                 Cure     1
# 166                    Successful_action     1
# 167                   Linguistic_meaning     1
# 168             Cause_change_of_strength     1
# 169                              Conduct     1
# 170                          Correctness     1
# 171                           Strictness     1
# 172                               Reason     1
# 173                    Social_connection     1
# 174                     Part_inner_outer     1
# 175                  Transition_to_state     1
# 176            Be_in_agreement_on_action     1
# 177                          Competition     1
# 178                         Ride_vehicle     1
# 179                   Architectural_part     1
# 180                        Compatibility     1
# 181                                 Sign     1
# 182                             Avoiding     1
# 183            Interior_profile_relation     1
# 184                             Delivery     1
# 185                         Execute_plan     1
# 186                             Rescuing     1
# 187                     Activity_ongoing     1
# 188                Change_event_duration     1
# 189                                Using     1
# 190                           Surpassing     1
# 191                     Active_substance     1
# 192                       Change_posture     1
# 193                              Funding     1
# 194                         Amounting_to     1
# 195                         Coming_to_be     1
# 196                        Communication     1
# 197                            Adjacency     1
# 198                            Direction     1
# 199                             Capacity     1
# 200                             Clothing     1
# 201                        Text_creation     1
# 202                      Operate_vehicle     1
# 203                  Position_on_a_scale     1
# 204                    Building_subparts     1
# 205                       Secrecy_status     1
# 206                   Success_or_failure     1
# 207                            Residence     1
# 208                           Membership     1
# 209                         Alternatives     1
# 210                            Expertise     1
# 211                               Attack     1
# 212                                 Rest     1
# 213                              Purpose     1
# 214                        Relative_time     1
# 215                          Information     1
# 216                      Body_decoration     1
# 217                        Exemplariness     1
# 218                               Entity     1
# 219                      Make_compromise     1
# 220                              Animals     1
# 221                 Cause_to_be_included     1
# 222                              Warning     1
# 223                               Origin     1
# 224                          Expectation     1
# 225                               Domain     1
# 226                           First_rank     1
# 227                 Intentionally_create     1
# 228              Rewards_and_punishments     1
# 229               Judgment_communication     1
# 230                           Usefulness     1
# 231                             Reliance     1
# 232                           Leadership     1
# 233                           Protecting     1
# 234                          Taking_time     1
# 235                       Calendric_unit     1
# 236                          Ingredients     1
# 237              Non-commutative_process     1
# 238                     Version_sequence     1
# 239                   Ranked_expectation     1
# 240                 Change_of_leadership     1
# 241                       State_continue     1
# 242             Having_or_lacking_access     1
# 243                         Desirability     1
# 244              Level_of_force_exertion     1
# 245                            Existence     1
# 246                      Toxic_substance     1
# 247                             Quantity     1
# 248                            Frugality     1
# 249                   Dominate_situation     1
# 250                             Offering     1
# 251                              Network     1
# 252                            Defending     1
# 253                             Exemplar     1

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                                    index  PRED
# 0                                    Age   185
# 1                                   Goal   138
# 2                              Aggregate    77
# 3                           Taking_sides    54
# 4                                 Degree    43
# 5             Change_position_on_a_scale    39
# 6                   Temporal_collocation    35
# 7                       Ingest_substance    34
# 8                                  Gizmo    30
# 9                        Being_in_effect    27
# 10                                 Means    26
# 11                    Medical_conditions    26
# 12                       Quantified_mass    25
# 13                            Possession    25
# 14                  Processing_materials    24
# 15                             Increment    24
# 16                        Measure_volume    21
# 17                               Placing    20
# 18                      Being_in_control    19
# 19                              Creating    19
# 20                           Progression    19
# 21                              Evidence    18
# 22                 Proportional_quantity    17
# 23                    Being_in_operation    17
# 24                            Importance    17
# 25                     Locative_relation    16
# 26                                  Food    15
# 27                              Exchange    15
# 28                         Accompaniment    14
# 29                           Contingency    14
# 30                                Giving    13
# 31                              Negation    12
# 32                           Possibility    12
# 33                     Political_locales    12
# 34   Cause_change_of_position_on_a_scale    12
# 35                                Custom    11
# 36                        Coming_up_with    11
# 37                   Earnings_and_losses    11
# 38                       Cause_expansion    10
# 39                                  Rite    10
# 40                               Verdict    10
# 41                           Agriculture    10
# 42                               Weather    10
# 43                             Statement    10
# 44                    People_by_vocation     9
# 45                       Performing_arts     9
# 46                        Required_event     9
# 47                            Capability     9
# 48                                Fields     9
# 49                            Assistance     8
# 50                Criminal_investigation     8
# 51                             Causation     8
# 52                   Objective_influence     8
# 53                     Intentionally_act     8
# 54                      Measure_duration     8
# 55                      Cardinal_numbers     8
# 56                           Time_vector     8
# 57                              Scrutiny     8
# 58                   Commutative_process     7
# 59                             Frequency     7
# 60                               Needing     7
# 61                                Supply     6
# 62                             Substance     6
# 63           Prevent_or_allow_possession     6
# 64                Undergo_transformation     5
# 65                         Being_at_risk     5
# 66                                 Topic     5
# 67                         Locale_by_use     5
# 68                              Instance     5
# 69                      Point_of_dispute     5
# 70                      Natural_features     5
# 71                               Control     5
# 72                Agree_or_refuse_to_act     5
# 73                    Part_orientational     5
# 74                           Self_motion     5
# 75                 Commutative_statement     5
# 76                                Weapon     5
# 77                              Labeling     4
# 78                            Stinginess     4
# 79                 Measurable_attributes     4
# 80                          Identicality     4
# 81                             Awareness     4
# 82                        Categorization     4
# 83                       Being_necessary     4
# 84                          Cause_change     4
# 85                         Extreme_value     4
# 86                            Concessive     4
# 87                     Speed_description     4
# 88                         Sole_instance     4
# 89                 Perception_experience     3
# 90                              Adducing     3
# 91                               Economy     3
# 92                             Assessing     3
# 93                           Suitability     3
# 94                               Filling     3
# 95                          Social_event     3
# 96                             Dispersal     3
# 97                         Expensiveness     3
# 98                     Behind_the_scenes     3
# 99                        Accomplishment     3
# 100                           Body_parts     3
# 101                 Explaining_the_facts     3
# 102                            Documents     3
# 103                          Carry_goods     3
# 104                  Social_desirability     3
# 105                           Likelihood     3
# 106                             Response     3
# 107                              Kinship     3
# 108                    Cause_to_perceive     3
# 109                            Surviving     3
# 110                                 Size     3
# 111                                Event     3
# 112                  Cause_to_amalgamate     3
# 113                           Satisfying     2
# 114                       Becoming_aware     2
# 115                      Risky_situation     2
# 116                       Food_gathering     2
# 117                              Storing     2
# 118                            Sensation     2
# 119                             Presence     2
# 120                          Catastrophe     2
# 121                  Have_as_requirement     2
# 122                           Limitation     2
# 123                           Conquering     2
# 124                 Performers_and_roles     2
# 125          Foreign_or_domestic_country     2
# 126           Continued_state_of_affairs     2
# 127                       Being_relevant     2
# 128                           Businesses     2
# 129                    Coming_to_believe     2
# 130                            Diversity     2
# 131                            Buildings     2
# 132                      Desirable_event     2
# 133                             Choosing     2
# 134                        Dead_or_alive     2
# 135                         Be_subset_of     2
# 136                       Precariousness     2
# 137                         Cause_motion     2
# 138                       Undergo_change     2
# 139            Body_description_holistic     2
# 140                      Distinctiveness     2
# 141                             Boundary     2
# 142                      Experimentation     2
# 143                           Commitment     2
# 144                          Obviousness     2
# 145                            Certainty     2
# 146                   Terms_of_agreement     2
# 147                             Dynamism     2
# 148                               Aiming     2
# 149                        Collaboration     2
# 150                            Dimension     2
# 151                          Intoxicants     2
# 152                    Duration_relation     2
# 153                           Path_shape     2
# 154                          Temperature     2
# 155           Condition_symptom_relation     2
# 156                             Research     2
# 157            Level_of_force_resistance     2
# 158                 Attitude_description     2
# 159               Improvement_or_decline     2
# 160                    Experiencer_focus     2
# 161                            Attention     1
# 162                 Distributed_position     1
# 163                                Color     1
# 164                  Operational_testing     1
# 165                                 Cure     1
# 166                    Successful_action     1
# 167                   Linguistic_meaning     1
# 168             Cause_change_of_strength     1
# 169                              Conduct     1
# 170                          Correctness     1
# 171                           Strictness     1
# 172                               Reason     1
# 173                    Social_connection     1
# 174                     Part_inner_outer     1
# 175                  Transition_to_state     1
# 176            Be_in_agreement_on_action     1
# 177                          Competition     1
# 178                         Ride_vehicle     1
# 179                   Architectural_part     1
# 180                        Compatibility     1
# 181                                 Sign     1
# 182                             Avoiding     1
# 183            Interior_profile_relation     1
# 184                             Delivery     1
# 185                         Execute_plan     1
# 186                             Rescuing     1
# 187                     Activity_ongoing     1
# 188                Change_event_duration     1
# 189                                Using     1
# 190                           Surpassing     1
# 191                     Active_substance     1
# 192                       Change_posture     1
# 193                              Funding     1
# 194                         Amounting_to     1
# 195                         Coming_to_be     1
# 196                        Communication     1
# 197                            Adjacency     1
# 198                            Direction     1
# 199                             Capacity     1
# 200                             Clothing     1
# 201                        Text_creation     1
# 202                      Operate_vehicle     1
# 203                  Position_on_a_scale     1
# 204                    Building_subparts     1
# 205                       Secrecy_status     1
# 206                   Success_or_failure     1
# 207                            Residence     1
# 208                           Membership     1
# 209                         Alternatives     1
# 210                            Expertise     1
# 211                               Attack     1
# 212                                 Rest     1
# 213                              Purpose     1
# 214                        Relative_time     1
# 215                          Information     1
# 216                      Body_decoration     1
# 217                        Exemplariness     1
# 218                               Entity     1
# 219                      Make_compromise     1
# 220                              Animals     1
# 221                 Cause_to_be_included     1
# 222                              Warning     1
# 223                               Origin     1
# 224                          Expectation     1
# 225                               Domain     1
# 226                           First_rank     1
# 227                 Intentionally_create     1
# 228              Rewards_and_punishments     1
# 229               Judgment_communication     1
# 230                           Usefulness     1
# 231                             Reliance     1
# 232                           Leadership     1
# 233                           Protecting     1
# 234                          Taking_time     1
# 235                       Calendric_unit     1
# 236                          Ingredients     1
# 237              Non-commutative_process     1
# 238                     Version_sequence     1
# 239                   Ranked_expectation     1
# 240                 Change_of_leadership     1
# 241                       State_continue     1
# 242             Having_or_lacking_access     1
# 243                         Desirability     1
# 244              Level_of_force_exertion     1
# 245                            Existence     1
# 246                      Toxic_substance     1
# 247                             Quantity     1
# 248                            Frugality     1
# 249                   Dominate_situation     1
# 250                             Offering     1
# 251                              Network     1
# 252                            Defending     1
# 253                             Exemplar     1

# %%
 getPlot(list_all,'PRED')
