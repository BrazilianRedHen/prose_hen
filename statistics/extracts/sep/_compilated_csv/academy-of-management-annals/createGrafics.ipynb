# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                                    index  PRED
# 0                                    Age   151
# 1                                   Goal    87
# 2                                 Degree    57
# 3                               Research    56
# 4                       Being_in_control    41
# 5                   Temporal_collocation    29
# 6                             Possession    28
# 7                     Being_in_operation    27
# 8                                  Means    26
# 9                              Aggregate    22
# 10                            Businesses    19
# 11                          Taking_sides    19
# 12                      Cardinal_numbers    18
# 13                       Quantified_mass    16
# 14                          Identicality    16
# 15                             Increment    16
# 16                              Scrutiny    15
# 17                              Evidence    14
# 18                          Organization    13
# 19                     Locative_relation    11
# 20                                Fields    10
# 21                      Measure_duration     9
# 22                 Proportional_quantity     9
# 23                      Natural_features     9
# 24                               Verdict     9
# 25                                 Topic     9
# 26                             Awareness     9
# 27                             Statement     9
# 28                                Supply     8
# 29                                  Size     8
# ..                                   ...   ...
# 190            Level_of_force_resistance     1
# 191            Biological_classification     1
# 192                         Cause_motion     1
# 193                         Cause_to_end     1
# 194                         Social_event     1
# 195                              Needing     1
# 196                             Deciding     1
# 197                             Visiting     1
# 198                              Network     1
# 199                            Deserving     1
# 200                          Obviousness     1
# 201                            Reasoning     1
# 202                      Toxic_substance     1
# 203                   Individual_history     1
# 204                      Resolve_problem     1
# 205                             Relation     1
# 206                  Information_display     1
# 207                            Sensation     1
# 208          Foreign_or_domestic_country     1
# 209                          Catastrophe     1
# 210                  Social_desirability     1
# 211       Mental_stimulus_stimulus_focus     1
# 212                           Undergoing     1
# 213                        Sole_instance     1
# 214                           Stinginess     1
# 215  Cause_change_of_position_on_a_scale     1
# 216           Continued_state_of_affairs     1
# 217                             Instance     1
# 218                              Seeking     1
# 219                        Relative_time     1
#
# [220 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-dc48103f1713> in <module>
#       1 allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
# ----> 2 list_all.to_excel(allFileName, index = None, header=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2125         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    2126                         startcol=startcol, freeze_panes=freeze_panes,
# -> 2127                         engine=engine)
#    2128
#    2129     def to_json(self, path_or_buf=None, orient=None, date_format=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     662                            freeze_panes=freeze_panes)
#     663         if need_save:
# --> 664             writer.save()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1675         Save workbook to disk.
#    1676         """
# -> 1677         return self.book.save(self.path)
#    1678
#    1679     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlwt\Workbook.py in save(self, filename_or_stream)
#     708
#     709         doc = CompoundDoc.XlsDoc()
# --> 710         doc.save(filename_or_stream, self.get_biff_data())
#     711
#     712
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlwt\CompoundDoc.py in save(self, file_name_or_filelike_obj, stream)
#     260         we_own_it = not hasattr(f, 'write')
#     261         if we_own_it:
# --> 262             f = open(file_name_or_filelike_obj, 'w+b')
#     263         f.write(self.header)
#     264         f.write(self.packed_MSAT_1st)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\excel\\academy-of-management-annals_all.xls'

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
