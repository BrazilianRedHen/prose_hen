# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                           index  PRED
# 0                           Age   108
# 1                          Goal    84
# 2                        Degree    60
# 3              Being_in_control    24
# 4                  Organization    21
# 5                  Taking_sides    21
# 6                    Possession    20
# 7              Cardinal_numbers    17
# 8                  Identicality    16
# 9                         Means    14
# 10         Temporal_collocation    14
# 11               Measure_volume    13
# 12                        Gizmo    13
# 13            Locative_relation    13
# 14                    Increment    12
# 15                     Research    11
# 16         Cognitive_connection    11
# 17           Being_in_operation    11
# 18              Quantified_mass    11
# 19                  Time_vector    10
# 20                   Quarreling     9
# 21      Level_of_force_exertion     9
# 22               Categorization     9
# 23          Objective_influence     9
# 24         Performers_and_roles     9
# 25                    Statement     8
# 26                       People     8
# 27                      Conduct     8
# 28                     Exchange     8
# 29                     Building     8
# ..                          ...   ...
# 172                 Progression     1
# 173            Process_continue     1
# 174  Continued_state_of_affairs     1
# 175                  Supporting     1
# 176                Coming_to_be     1
# 177                   Receiving     1
# 178         Information_display     1
# 179              Being_up_to_it     1
# 180              Calendric_unit     1
# 181                      Motion     1
# 182              State_continue     1
# 183             Cause_expansion     1
# 184                Being_active     1
# 185             Achieving_first     1
# 186               Communication     1
# 187                  Typicality     1
# 188                    Legality     1
# 189               Collaboration     1
# 190                    Presence     1
# 191                    Removing     1
# 192                      Weapon     1
# 193                     Revenge     1
# 194                        Cure     1
# 195                Cause_motion     1
# 196              Becoming_aware     1
# 197             Ordinal_numbers     1
# 198               Sole_instance     1
# 199           Building_subparts     1
# 200          Success_or_failure     1
# 201             Being_necessary     1
#
# [202 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
