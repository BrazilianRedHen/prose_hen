# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
pd.set_option('display.max_rows',None)

# %%
list_head
# Out:
#                     index  PRED
# 0            Taking_sides    10
# 1                     Age     5
# 2      Being_in_operation     4
# 3   Part_ordered_segments     2
# 4                Evidence     2
# 5   Proportional_quantity     2
# 6                    Goal     2
# 7             Progression     2
# 8        Ingest_substance     1
# 9    Temporal_collocation     1
# 10          Relative_time     1
# 11       Cardinal_numbers     1
# 12          Extreme_value     1
# 13               Dynamism     1
# 14      Coming_to_believe     1

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                                    index  PRED
# 0                                    Age    65
# 1                                   Goal    31
# 2                           Taking_sides    27
# 3                             Possession    16
# 4                          Extreme_value    15
# 5                            Progression    13
# 6                         Measure_volume    13
# 7                                 Degree    13
# 8                   Temporal_collocation    13
# 9                               Research    10
# 10                  Processing_materials    10
# 11                                 Means    10
# 12                                 Gizmo     9
# 13                 Proportional_quantity     9
# 14                           Time_vector     8
# 15               Level_of_force_exertion     8
# 16                       Performing_arts     8
# 17                   Social_desirability     8
# 18                             Substance     7
# 19                        Accomplishment     7
# 20                                 Topic     7
# 21                     Locative_relation     7
# 22                      Measure_duration     6
# 23                     Building_subparts     6
# 24                         Expensiveness     5
# 25                         Relative_time     5
# 26                               Purpose     5
# 27                      Cardinal_numbers     5
# 28                                  Size     5
# 29                           Temperature     4
# 30                    Being_in_operation     4
# 31                         Dead_or_alive     4
# 32                           Summarizing     4
# 33                             Statement     4
# 34                                Giving     4
# 35                       Operate_vehicle     4
# 36                           Self_motion     4
# 37                            Importance     4
# 38                       Quantified_mass     4
# 39                       Resolve_problem     3
# 40                             Attention     3
# 41                             Causation     3
# 42                             Aggregate     3
# 43                       Being_necessary     3
# 44                    Medical_conditions     3
# 45                           Electricity     3
# 46                Criminal_investigation     3
# 47                         Accompaniment     3
# 48                             Increment     3
# 49                      Cooking_creation     3
# 50                          Desirability     3
# 51                         Manufacturing     3
# 52                      Ingest_substance     3
# 53   Cause_change_of_position_on_a_scale     3
# 54                           Contingency     3
# 55                       Cause_expansion     3
# 56                                Supply     2
# 57                                  Text     2
# 58                     Intentionally_act     2
# 59                 Part_ordered_segments     2
# 60                           Obviousness     2
# 61                      Natural_features     2
# 62                            Capability     2
# 63                              Evidence     2
# 64                       Being_in_effect     2
# 65                  Intentionally_create     2
# 66                       Attempt_suasion     2
# 67                           Suitability     2
# 68                          Coming_to_be     2
# 69                  Distributed_position     2
# 70                      Point_of_dispute     2
# 71                              Response     2
# 72                              Instance     2
# 73                        Coming_up_with     2
# 74                              Dynamism     2
# 75                        Precariousness     2
# 76                        Required_event     2
# 77                           Predicament     2
# 78                               Storing     2
# 79                Undergo_transformation     1
# 80                     Coming_to_believe     1
# 81                             Residence     1
# 82                        State_continue     1
# 83                           Emphasizing     1
# 84                            Stinginess     1
# 85                             Direction     1
# 86                          Cause_motion     1
# 87                 Measurable_attributes     1
# 88                            Similarity     1
# 89                   Imposing_obligation     1
# 90                               Attempt     1
# 91                               Protest     1
# 92                             Diversity     1
# 93                             Frequency     1
# 94                        Becoming_aware     1
# 95                              Bringing     1
# 96                                 Death     1
# 97                        Being_employed     1
# 98                             Dimension     1
# 99                            Likelihood     1
# 100                             Labeling     1
# 101                        Communication     1
# 102                               People     1
# 103                 Performers_and_roles     1
# 104                     Version_sequence     1
# 105                             Roadways     1
# 106                    Social_connection     1
# 107                  Commutative_process     1
# 108                               Aiming     1
# 109                             Quantity     1
# 110                    Duration_relation     1
# 111                          Ingredients     1
# 112                                 Luck     1
# 113                              Control     1
# 114                Commutative_statement     1
# 115           Condition_symptom_relation     1
# 116                        Labor_product     1
# 117                      Desirable_event     1
# 118                              Needing     1
# 119               Judgment_communication     1
# 120                  Earnings_and_losses     1
# 121                        Being_at_risk     1
# 122                                  Sex     1
# 123                  Information_display     1
# 124                               Locale     1
# 125                      Activity_finish     1
# 126                           Body_parts     1
# 127                    Cause_to_perceive     1
# 128                              Network     1
# 129                            Dispersal     1
# 130                   Success_or_failure     1
# 131                    Behind_the_scenes     1
# 132                            Employing     1
# 133       Mental_stimulus_stimulus_focus     1
# 134                             Delivery     1
# 135            Level_of_force_resistance     1
# 136                          Opportunity     1
# 137                 Intentionally_affect     1
# 138                              Filling     1
# 139                         Organization     1
# 140                            Awareness     1
# 141                              Vehicle     1
# 142            Interior_profile_relation     1
# 143                             Negation     1
# 144                      Achieving_first     1
# 145                             Judgment     1
# 146                            Reporting     1
# 147        Social_interaction_evaluation     1
# 148                         Be_subset_of     1
# 149                           Concessive     1
# 150                             Creating     1
# 151                    Speed_description     1
# 152                             Relation     1
# 153                           Part_whole     1
# 154                   Ranked_expectation     1
# 155                         Cause_change     1
# 156                           Compliance     1
# 157                             Clothing     1
# 158                         Identicality     1
# 159                                 Work     1
# 160           Change_position_on_a_scale     1

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                                    index  PRED
# 0                                    Age    70
# 1                           Taking_sides    37
# 2                                   Goal    33
# 3                          Extreme_value    16
# 4                             Possession    16
# 5                            Progression    15
# 6                   Temporal_collocation    14
# 7                                 Degree    13
# 8                         Measure_volume    13
# 9                  Proportional_quantity    11
# 10                                 Means    10
# 11                              Research    10
# 12                  Processing_materials    10
# 13                                 Gizmo     9
# 14                    Being_in_operation     8
# 15                       Performing_arts     8
# 16               Level_of_force_exertion     8
# 17                   Social_desirability     8
# 18                           Time_vector     8
# 19                                 Topic     7
# 20                        Accomplishment     7
# 21                     Locative_relation     7
# 22                             Substance     7
# 23                      Measure_duration     6
# 24                         Relative_time     6
# 25                     Building_subparts     6
# 26                      Cardinal_numbers     6
# 27                         Expensiveness     5
# 28                               Purpose     5
# 29                                  Size     5
# 30                           Summarizing     4
# 31                           Temperature     4
# 32                            Importance     4
# 33                         Dead_or_alive     4
# 34                                Giving     4
# 35                           Self_motion     4
# 36                              Evidence     4
# 37                      Ingest_substance     4
# 38                       Operate_vehicle     4
# 39                 Part_ordered_segments     4
# 40                             Statement     4
# 41                       Quantified_mass     4
# 42                       Resolve_problem     3
# 43                             Aggregate     3
# 44                             Attention     3
# 45                       Being_necessary     3
# 46                Criminal_investigation     3
# 47                             Causation     3
# 48                    Medical_conditions     3
# 49                           Electricity     3
# 50   Cause_change_of_position_on_a_scale     3
# 51                             Increment     3
# 52                       Cause_expansion     3
# 53                      Cooking_creation     3
# 54                         Manufacturing     3
# 55                          Desirability     3
# 56                           Contingency     3
# 57                         Accompaniment     3
# 58                              Dynamism     3
# 59                                  Text     2
# 60                     Intentionally_act     2
# 61                           Obviousness     2
# 62                                Supply     2
# 63                      Natural_features     2
# 64                            Capability     2
# 65                          Coming_to_be     2
# 66                       Being_in_effect     2
# 67                  Intentionally_create     2
# 68                           Suitability     2
# 69                       Attempt_suasion     2
# 70                     Coming_to_believe     2
# 71                  Distributed_position     2
# 72                        Precariousness     2
# 73                              Response     2
# 74                        Required_event     2
# 75                           Predicament     2
# 76                        Coming_up_with     2
# 77                              Instance     2
# 78                      Point_of_dispute     2
# 79                               Storing     2
# 80                               Attempt     1
# 81                              Labeling     1
# 82                            Likelihood     1
# 83                              Bringing     1
# 84                        Being_employed     1
# 85                             Residence     1
# 86                        State_continue     1
# 87                           Emphasizing     1
# 88                               Protest     1
# 89                        Becoming_aware     1
# 90                             Direction     1
# 91            Condition_symptom_relation     1
# 92                             Diversity     1
# 93                            Similarity     1
# 94                             Frequency     1
# 95                          Cause_motion     1
# 96                  Intentionally_affect     1
# 97                 Commutative_statement     1
# 98                               Control     1
# 99                 Measurable_attributes     1
# 100                           Stinginess     1
# 101                            Dimension     1
# 102                                 Luck     1
# 103                    Duration_relation     1
# 104                    Social_connection     1
# 105               Undergo_transformation     1
# 106                  Imposing_obligation     1
# 107                        Communication     1
# 108                               People     1
# 109                 Performers_and_roles     1
# 110                     Version_sequence     1
# 111                             Roadways     1
# 112                  Commutative_process     1
# 113                               Aiming     1
# 114                             Quantity     1
# 115                          Ingredients     1
# 116                                Death     1
# 117                             Judgment     1
# 118                              Needing     1
# 119                           Body_parts     1
# 120                            Dispersal     1
# 121                              Filling     1
# 122                  Earnings_and_losses     1
# 123                        Being_at_risk     1
# 124                                  Sex     1
# 125                  Information_display     1
# 126                               Locale     1
# 127                              Network     1
# 128                    Cause_to_perceive     1
# 129                      Activity_finish     1
# 130                    Behind_the_scenes     1
# 131       Mental_stimulus_stimulus_focus     1
# 132                   Success_or_failure     1
# 133            Level_of_force_resistance     1
# 134                            Employing     1
# 135                          Opportunity     1
# 136                             Delivery     1
# 137                            Awareness     1
# 138               Judgment_communication     1
# 139                         Organization     1
# 140                        Labor_product     1
# 141                             Relation     1
# 142                      Desirable_event     1
# 143            Interior_profile_relation     1
# 144                             Negation     1
# 145                      Achieving_first     1
# 146                           Concessive     1
# 147                            Reporting     1
# 148        Social_interaction_evaluation     1
# 149                         Be_subset_of     1
# 150                              Vehicle     1
# 151                                 Work     1
# 152                             Creating     1
# 153                   Ranked_expectation     1
# 154                           Part_whole     1
# 155                         Cause_change     1
# 156                           Compliance     1
# 157                             Clothing     1
# 158                    Speed_description     1
# 159                         Identicality     1
# 160           Change_position_on_a_scale     1

# %%
 getPlot(list_all,'PRED')
