# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                           index  PRED
# 0                           Age   197
# 1                          Goal   146
# 2                  Taking_sides    42
# 3                        Degree    40
# 4                    Possession    33
# 5                      Evidence    31
# 6          Temporal_collocation    26
# 7    Change_position_on_a_scale    26
# 8                         Gizmo    25
# 9                         Means    23
# 10             Being_in_control    23
# 11              Quantified_mass    23
# 12                    Aggregate    23
# 13           Being_in_operation    21
# 14             Ingest_substance    21
# 15                    Substance    19
# 16               Measure_volume    18
# 17           Medical_conditions    17
# 18                Accompaniment    16
# 19                       Giving    16
# 20                         Food    15
# 21                      Placing    15
# 22                     Research    14
# 23                  Contingency    14
# 24                    Increment    14
# 25            Political_locales    13
# 26                      Needing    13
# 27              Being_in_effect    12
# 28                       Custom    11
# 29                  Possibility    11
# ..                          ...   ...
# 222                     Attempt     1
# 223           Experiencer_focus     1
# 224             Estimated_value     1
# 225                 Predicament     1
# 226           Building_subparts     1
# 227       Perception_experience     1
# 228                    Reliance     1
# 229                   Posing_as     1
# 230                 Temperature     1
# 231                    Quantity     1
# 232                    Labeling     1
# 233                        Fame     1
# 234                   Dimension     1
# 235                 Correctness     1
# 236         Expressing_publicly     1
# 237             Toxic_substance     1
# 238        Duration_description     1
# 239                      Origin     1
# 240                      Hiring     1
# 241              Being_relevant     1
# 242                     Funding     1
# 243             Spatial_contact     1
# 244              State_continue     1
# 245               Exemplariness     1
# 246               Relative_time     1
# 247                   Expansion     1
# 248         Position_on_a_scale     1
# 249                       Event     1
# 250        Medical_intervention     1
# 251                   Dispersal     1
#
# [252 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
