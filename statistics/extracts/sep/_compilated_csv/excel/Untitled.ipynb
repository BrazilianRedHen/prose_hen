# %%
import pandas as pd
import glob

path = r'C:\Users\Rubens\Workspace\prosehen\sep\_compilated_csv\excel' # use your path
all_files = glob.glob(path + "/*.xls")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
MyEmptydf = pd.DataFrame(columns=['index','PRED'])

# %%
df = li[0].set_index('index').add(li[0].set_index('index'), fill_value=0).reset_index()

# %%
for i in li:
    MyEmptydf = MyEmptydf.set_index('index').add(i.set_index('index'), fill_value=0).reset_index()

# %%
MyEmptydf.sort_values(by="PRED",ascending=0)

MyEmptydf.sort_values(by="PRED",ascending=0).to_excel("all_frames.xls", index = None, header=True)

# %%
# Out:
#      level_0                       index  PRED
# 0         13                         Age  6786
# 1        270                        Goal  4266
# 2        539                Taking_sides  1840
# 3        173                      Degree  1829
# 4        415                  Possession  1073
# 5        342                       Means  1048
# 6        543        Temporal_collocation   919
# 7        269                       Gizmo   877
# 8         59          Being_in_operation   834
# 9        222                    Evidence   812
# 10       437             Quantified_mass   778
# 11        85            Cardinal_numbers   733
# 12        14                   Aggregate   654
# 13       468                    Research   649
# 14       295            Ingest_substance   647
# 15       289                   Increment   571
# 16       347              Measure_volume   546
# 17       345            Measure_duration   524
# 18       348          Medical_conditions   519
# ...
