# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                           index  PRED
# 0                          Goal   151
# 1                           Age   139
# 2                     Aggregate    55
# 3                      Exchange    50
# 4                  Taking_sides    45
# 5    Change_position_on_a_scale    39
# 6                        Degree    38
# 7                      Evidence    34
# 8               Being_in_effect    28
# 9            Being_in_operation    25
# 10        Proportional_quantity    23
# 11              Quantified_mass    22
# 12         Temporal_collocation    22
# 13                   Possession    22
# 14             Measure_duration    22
# 15             Ingest_substance    19
# 16                    Substance    18
# 17                        Gizmo    17
# 18                   Capability    15
# 19                  Contingency    14
# 20          Commutative_process    14
# 21                     Creating    14
# 22            Political_locales    14
# 23                      Placing    13
# 24                     Negation    12
# 25                    Assessing    12
# 26   Condition_symptom_relation    12
# 27                     Quantity    11
# 28                Accompaniment    11
# 29             Cardinal_numbers    11
# ..                          ...   ...
# 197           Commerce_scenario     1
# 198         Have_as_requirement     1
# 199                      People     1
# 200              Accomplishment     1
# 201              State_continue     1
# 202                  Discussion     1
# 203   Be_in_agreement_on_action     1
# 204                    Accuracy     1
# 205                    Avoiding     1
# 206         Cause_to_amalgamate     1
# 207                   Dispersal     1
# 208             Mental_property     1
# 209    Having_or_lacking_access     1
# 210                 Competition     1
# 211                 Opportunity     1
# 212                    Reliance     1
# 213       Perception_experience     1
# 214        Subjective_influence     1
# 215              Secrecy_status     1
# 216                 Taking_time     1
# 217                Amounting_to     1
# 218          Education_teaching     1
# 219            Activity_ongoing     1
# 220           Coming_to_believe     1
# 221          Architectural_part     1
# 222                    Scrutiny     1
# 223                      Shapes     1
# 224         Cause_to_make_noise     1
# 225                        Text     1
# 226                        Type     1
#
# [227 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
