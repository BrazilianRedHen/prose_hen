# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                              index  PRED
# 0                              Age   116
# 1                             Goal    94
# 2                          Network    69
# 3                         Bringing    42
# 4                     Taking_sides    36
# 5                             Size    34
# 6                           Degree    26
# 7             Temporal_collocation    18
# 8                   Measure_volume    17
# 9                          Purpose    14
# 10                 Performing_arts    13
# 11                 Quantified_mass    13
# 12                           Means    12
# 13                        Evidence    12
# 14                     Progression    12
# 15                       Increment    12
# 16                            Rite    11
# 17                   Being_at_risk    10
# 18                Natural_features    10
# 19                          Fields    10
# 20             Communication_means    10
# 21                           Gizmo    10
# 22                      Possession    10
# 23              Being_in_operation     9
# 24                   Accompaniment     9
# 25               Locative_relation     8
# 26      Change_position_on_a_scale     8
# 27                Point_of_dispute     8
# 28                Being_in_control     8
# 29                         Control     8
# ..                             ...   ...
# 188                      Sensation     1
# 189                Being_in_effect     1
# 190                         Origin     1
# 191                 Being_employed     1
# 192           Intentionally_create     1
# 193                     Protecting     1
# 194                   Dough_rising     1
# 195                        Storing     1
# 196                Cause_expansion     1
# 197                       Clothing     1
# 198        Level_of_force_exertion     1
# 199                     Cogitation     1
# 200                     Similarity     1
# 201                     Stinginess     1
# 202            People_by_residence     1
# 203                     Path_shape     1
# 204                     Scheduling     1
# 205                  Exemplariness     1
# 206                      Dispersal     1
# 207    Prevent_or_allow_possession     1
# 208                       Quantity     1
# 209              Assigned_location     1
# 210                   Social_event     1
# 211                 Change_posture     1
# 212                  Collaboration     1
# 213                 Stimulus_focus     1
# 214  Directional_locative_relation     1
# 215        Connecting_architecture     1
# 216              System_complexity     1
# 217                 Precariousness     1
#
# [218 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
