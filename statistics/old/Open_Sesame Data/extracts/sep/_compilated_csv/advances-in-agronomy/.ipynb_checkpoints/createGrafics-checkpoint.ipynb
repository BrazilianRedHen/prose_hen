# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
pd.set_option('display.max_rows',None)

# %%
list_head
# Out:
#                                   index  PRED
# 0                                   Age    10
# 1                          Taking_sides     6
# 2                                  Goal     5
# 3                                Degree     4
# 4                                  Food     3
# 5                    Being_in_operation     2
# 6                     Political_locales     2
# 7                                Locale     2
# 8                                 Gizmo     2
# 9                            Possession     2
# 10                               Custom     2
# 11                  Transition_to_state     1
# 12                     Measure_duration     1
# 13                              Needing     1
# 14                     Process_continue     1
# 15                          Contingency     1
# 16                            Increment     1
# 17                              Placing     1
# 18                            Aggregate     1
# 19                     Cardinal_numbers     1
# 20                 Cognitive_connection     1
# 21                          Agriculture     1
# 22  Cause_change_of_position_on_a_scale     1
# 23                             Creating     1
# 24           Continued_state_of_affairs     1
# 25                 Duration_description     1
# 26                         Representing     1
# 27                        Dead_or_alive     1
# 28                 Performers_and_roles     1
# 29                         Organization     1
# 30                               Giving     1
# 31                     Ingest_substance     1
# 32                          Sufficiency     1
# 33                            Causation     1
# 34           Condition_symptom_relation     1
# 35                   Medical_conditions     1
# 36                             Response     1
# 37                                Means     1
# 38                      Achieving_first     1
# 39                        Sole_instance     1
# 40                       Measure_volume     1
# 41                     Being_in_control     1
# 42                 Temporal_collocation     1
# 43                      Being_necessary     1
# 44                                 Rite     1
# 45                             Evidence     1
# 46                            Awareness     1

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                                    index  PRED
# 0                                    Age   187
# 1                                   Goal   141
# 2                           Taking_sides    36
# 3                                 Degree    36
# 4                             Possession    31
# 5                               Evidence    30
# 6             Change_position_on_a_scale    26
# 7                   Temporal_collocation    25
# 8                        Quantified_mass    23
# 9                                  Gizmo    23
# 10                                 Means    22
# 11                             Aggregate    22
# 12                      Being_in_control    22
# 13                      Ingest_substance    20
# 14                             Substance    19
# 15                    Being_in_operation    19
# 16                        Measure_volume    17
# 17                         Accompaniment    16
# 18                    Medical_conditions    16
# 19                                Giving    15
# 20                              Research    14
# 21                               Placing    14
# 22                           Contingency    13
# 23                             Increment    13
# 24                                  Food    12
# 25                               Needing    12
# 26                       Being_in_effect    12
# 27                     Political_locales    11
# 28                           Possibility    11
# 29                            Businesses    11
# 30                     Locative_relation    10
# 31                 Proportional_quantity    10
# 32                         Being_at_risk    10
# 33                   Earnings_and_losses    10
# 34                                Custom     9
# 35                      Measure_duration     9
# 36                                Fields     9
# 37                           Progression     9
# 38   Cause_change_of_position_on_a_scale     9
# 39                           Agriculture     9
# 40                      Cardinal_numbers     8
# 41                                Supply     8
# 42                           Time_vector     8
# 43                           Competition     8
# 44                   Have_as_requirement     8
# 45                              Negation     8
# 46                    People_by_vocation     8
# 47                            Importance     8
# 48                            Part_whole     7
# 49                        Categorization     7
# 50                     Intentionally_act     7
# 51                        Required_event     7
# 52                               Filling     7
# 53                      Point_of_dispute     7
# 54                         Locale_by_use     7
# 55                             Assessing     7
# 56                  Processing_materials     7
# 57                             Diversity     7
# 58                          Cause_change     7
# 59                             Causation     6
# 60                            Capability     6
# 61                               Control     6
# 62                             Frugality     6
# 63                              Presence     6
# 64                              Exchange     6
# 65                           Intoxicants     5
# 66                      Natural_features     5
# 67                   Social_desirability     5
# 68                             Statement     5
# 69                         Sole_instance     5
# 70                          Organization     5
# 71                          Be_subset_of     5
# 72                              Creating     5
# 73                              Instance     5
# 74                           Summarizing     5
# 75                             Awareness     5
# 76                   Objective_influence     5
# 77                         Extreme_value     5
# 78                                  Size     4
# 79                           Self_motion     4
# 80                  Cause_to_be_included     4
# 81                               Purpose     4
# 82                          Social_event     4
# 83                                Weapon     4
# 84                            Limitation     4
# 85                             Attaching     4
# 86                             Sensation     4
# 87                       Operate_vehicle     4
# 88                Judgment_communication     4
# 89            Condition_symptom_relation     4
# 90                              Exemplar     4
# 91                                 Topic     3
# 92                               Weather     3
# 93                              Recovery     3
# 94                        Coming_up_with     3
# 95                              Scrutiny     3
# 96                  Cognitive_connection     3
# 97                            Discussion     3
# 98                       Cause_expansion     3
# 99                               Project     3
# 100                  Imposing_obligation     3
# 101                Measurable_attributes     3
# 102                            Frequency     3
# 103                        Expensiveness     3
# 104                          Information     3
# 105                          Ingredients     3
# 106                      Desirable_event     3
# 107                               People     3
# 108                   Education_teaching     3
# 109                 Performers_and_roles     3
# 110                          Suitability     3
# 111                  Information_display     3
# 112                    Duration_relation     3
# 113                Part_ordered_segments     3
# 114                        Communication     3
# 115                                Craft     3
# 116                           Assistance     3
# 117           Communicate_categorization     2
# 118                           Commitment     2
# 119                  Specific_individual     2
# 120                                  Sex     2
# 121                      Risky_situation     2
# 122            Interior_profile_relation     2
# 123                       Calendric_unit     2
# 124               Undergo_transformation     2
# 125          Prevent_or_allow_possession     2
# 126                            Reporting     2
# 127                            Deserving     2
# 128                  Cause_to_amalgamate     2
# 129                      Distinctiveness     2
# 130                             Removing     2
# 131                      Experiencer_obj     2
# 132                       Becoming_aware     2
# 133                          Emphasizing     2
# 134                        Collaboration     2
# 135                             Relation     2
# 136                     Part_inner_outer     2
# 137                    Successful_action     2
# 138                                 Text     2
# 139                     Process_continue     2
# 140                             Deciding     2
# 141                             Dynamism     2
# 142                           Conquering     2
# 143                    Behind_the_scenes     2
# 144                      Being_necessary     2
# 145                           Concessive     2
# 146                                Death     2
# 147              Level_of_force_exertion     2
# 148                           Protecting     2
# 149           Continued_state_of_affairs     2
# 150                         Identicality     2
# 151                              Animals     2
# 152                  Cause_to_make_noise     2
# 153                      Experimentation     2
# 154                          Carry_goods     2
# 155                                 Rite     2
# 156               Criminal_investigation     2
# 157                      Achieving_first     2
# 158                              Kinship     2
# 159                               Aiming     2
# 160                      Attempt_suasion     2
# 161                   Success_or_failure     2
# 162                             Response     2
# 163                   Part_orientational     2
# 164                       State_continue     1
# 165                        Exemplariness     1
# 166                    Cause_to_perceive     1
# 167            Make_cognitive_connection     1
# 168                          Temperature     1
# 169                       Precariousness     1
# 170        Social_interaction_evaluation     1
# 171                               Origin     1
# 172                         Dough_rising     1
# 173                                Color     1
# 174                      Spatial_contact     1
# 175                       Change_posture     1
# 176                Commutative_statement     1
# 177                             Labeling     1
# 178                          Correctness     1
# 179                            Dispersal     1
# 180                         Amounting_to     1
# 181                              Funding     1
# 182                            Ground_up     1
# 183                          Obviousness     1
# 184                      Resolve_problem     1
# 185                            Residence     1
# 186                            Direction     1
# 187                             Quantity     1
# 188                          Expectation     1
# 189                            Expansion     1
# 190                               Reason     1
# 191                    Experiencer_focus     1
# 192            Non-commutative_statement     1
# 193                               Prison     1
# 194                    Stage_of_progress     1
# 195                            Attention     1
# 196                              Economy     1
# 197                            Documents     1
# 198                           Estimating     1
# 199                         Cause_motion     1
# 200                         Institutions     1
# 201                              Conduct     1
# 202                      Being_obligated     1
# 203                 Intentionally_create     1
# 204                    Hostile_encounter     1
# 205                      Estimated_value     1
# 206                       Undergo_change     1
# 207                           Undressing     1
# 208                            Buildings     1
# 209                  Transition_to_state     1
# 210                Perception_experience     1
# 211                      Toxic_substance     1
# 212                                 Fame     1
# 213                    Coming_to_believe     1
# 214                           Cogitation     1
# 215                     Chemical_potency     1
# 216                       Being_relevant     1
# 217                             Reliance     1
# 218             Cause_change_of_strength     1
# 219                             Building     1
# 220                               Locale     1
# 221                           Body_parts     1
# 222                  Expressing_publicly     1
# 223                        Dead_or_alive     1
# 224              Rewards_and_punishments     1
# 225                            Posing_as     1
# 226                     Active_substance     1
# 227                              Attempt     1
# 228                        Relative_time     1
# 229                 Medical_intervention     1
# 230                        Reveal_secret     1
# 231                      Ordinal_numbers     1
# 232                                Event     1
# 233                      Performing_arts     1
# 234                             Scarcity     1
# 235                  Position_on_a_scale     1
# 236                    Building_subparts     1
# 237                            Dimension     1
# 238                           Typicality     1
# 239                  Commutative_process     1
# 240                          Predicament     1
# 241                              Destiny     1
# 242                Evaluative_comparison     1
# 243                             Desiring     1
# 244                             Offering     1
# 245                              Verdict     1
# 246                       Accomplishment     1
# 247                               Hiring     1
# 248                                 Luck     1

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                                    index  PRED
# 0                                    Age   197
# 1                                   Goal   146
# 2                           Taking_sides    42
# 3                                 Degree    40
# 4                             Possession    33
# 5                               Evidence    31
# 6                   Temporal_collocation    26
# 7             Change_position_on_a_scale    26
# 8                                  Gizmo    25
# 9                        Quantified_mass    23
# 10                             Aggregate    23
# 11                      Being_in_control    23
# 12                                 Means    23
# 13                      Ingest_substance    21
# 14                    Being_in_operation    21
# 15                             Substance    19
# 16                        Measure_volume    18
# 17                    Medical_conditions    17
# 18                                Giving    16
# 19                         Accompaniment    16
# 20                               Placing    15
# 21                                  Food    15
# 22                              Research    14
# 23                             Increment    14
# 24                           Contingency    14
# 25                     Political_locales    13
# 26                               Needing    13
# 27                       Being_in_effect    12
# 28                            Businesses    11
# 29                                Custom    11
# 30                           Possibility    11
# 31                 Proportional_quantity    10
# 32                     Locative_relation    10
# 33                           Agriculture    10
# 34                         Being_at_risk    10
# 35                   Earnings_and_losses    10
# 36                      Measure_duration    10
# 37   Cause_change_of_position_on_a_scale    10
# 38                                Fields     9
# 39                      Cardinal_numbers     9
# 40                           Progression     9
# 41                           Competition     8
# 42                           Time_vector     8
# 43                            Importance     8
# 44                              Negation     8
# 45                   Have_as_requirement     8
# 46                                Supply     8
# 47                    People_by_vocation     8
# 48                               Filling     7
# 49                        Required_event     7
# 50                          Cause_change     7
# 51                      Point_of_dispute     7
# 52                  Processing_materials     7
# 53                             Assessing     7
# 54                        Categorization     7
# 55                             Diversity     7
# 56                             Causation     7
# 57                     Intentionally_act     7
# 58                            Part_whole     7
# 59                         Locale_by_use     7
# 60                              Presence     6
# 61                              Creating     6
# 62                              Exchange     6
# 63                         Sole_instance     6
# 64                             Awareness     6
# 65                             Frugality     6
# 66                               Control     6
# 67                            Capability     6
# 68                          Organization     6
# 69                      Natural_features     5
# 70                           Intoxicants     5
# 71                           Summarizing     5
# 72                   Objective_influence     5
# 73                   Social_desirability     5
# 74                             Statement     5
# 75                         Extreme_value     5
# 76                          Be_subset_of     5
# 77            Condition_symptom_relation     5
# 78                              Instance     5
# 79                Judgment_communication     4
# 80                              Exemplar     4
# 81                       Operate_vehicle     4
# 82                                  Size     4
# 83                  Cause_to_be_included     4
# 84                  Cognitive_connection     4
# 85                                Weapon     4
# 86                               Purpose     4
# 87                          Social_event     4
# 88                           Self_motion     4
# 89                            Limitation     4
# 90                             Sensation     4
# 91                  Performers_and_roles     4
# 92                             Attaching     4
# 93                              Scrutiny     3
# 94                        Coming_up_with     3
# 95                                  Rite     3
# 96                       Being_necessary     3
# 97                              Response     3
# 98                       Achieving_first     3
# 99                   Imposing_obligation     3
# 100                        Expensiveness     3
# 101                            Frequency     3
# 102                          Ingredients     3
# 103                          Information     3
# 104                Measurable_attributes     3
# 105                      Cause_expansion     3
# 106                                Topic     3
# 107                              Weather     3
# 108                           Discussion     3
# 109                              Project     3
# 110           Continued_state_of_affairs     3
# 111                             Recovery     3
# 112                      Desirable_event     3
# 113                                Craft     3
# 114                        Communication     3
# 115                               People     3
# 116                    Duration_relation     3
# 117                  Information_display     3
# 118                   Education_teaching     3
# 119                          Suitability     3
# 120                               Locale     3
# 121                           Assistance     3
# 122                     Process_continue     3
# 123                Part_ordered_segments     3
# 124                  Specific_individual     2
# 125                                  Sex     2
# 126                      Risky_situation     2
# 127                             Dynamism     2
# 128           Communicate_categorization     2
# 129                             Deciding     2
# 130                       Becoming_aware     2
# 131                               Aiming     2
# 132                        Collaboration     2
# 133                        Dead_or_alive     2
# 134          Prevent_or_allow_possession     2
# 135                          Emphasizing     2
# 136            Interior_profile_relation     2
# 137                       Calendric_unit     2
# 138               Undergo_transformation     2
# 139                           Commitment     2
# 140                             Removing     2
# 141                            Deserving     2
# 142                      Distinctiveness     2
# 143                              Kinship     2
# 144                            Reporting     2
# 145                  Cause_to_amalgamate     2
# 146                           Protecting     2
# 147               Criminal_investigation     2
# 148                              Animals     2
# 149                                 Text     2
# 150                      Experiencer_obj     2
# 151                                Death     2
# 152                    Successful_action     2
# 153                   Part_orientational     2
# 154              Level_of_force_exertion     2
# 155                           Concessive     2
# 156                           Conquering     2
# 157                      Attempt_suasion     2
# 158                          Carry_goods     2
# 159                     Part_inner_outer     2
# 160                      Experimentation     2
# 161                             Relation     2
# 162                   Success_or_failure     2
# 163                  Cause_to_make_noise     2
# 164                  Transition_to_state     2
# 165                    Behind_the_scenes     2
# 166                         Identicality     2
# 167                    Cause_to_perceive     1
# 168                          Temperature     1
# 169                       State_continue     1
# 170                                Color     1
# 171                Commutative_statement     1
# 172                             Labeling     1
# 173                       Precariousness     1
# 174        Social_interaction_evaluation     1
# 175                               Origin     1
# 176                              Funding     1
# 177                               Prison     1
# 178                    Experiencer_focus     1
# 179                           Cogitation     1
# 180                        Exemplariness     1
# 181            Make_cognitive_connection     1
# 182                         Dough_rising     1
# 183                      Spatial_contact     1
# 184                    Stage_of_progress     1
# 185                            Expansion     1
# 186                          Obviousness     1
# 187            Non-commutative_statement     1
# 188                       Change_posture     1
# 189                          Correctness     1
# 190                            Dispersal     1
# 191                            Ground_up     1
# 192                      Resolve_problem     1
# 193                            Residence     1
# 194                            Direction     1
# 195                             Quantity     1
# 196                          Expectation     1
# 197                               Reason     1
# 198                         Amounting_to     1
# 199                  Position_on_a_scale     1
# 200                              Attempt     1
# 201                            Documents     1
# 202                  Expressing_publicly     1
# 203                         Cause_motion     1
# 204                              Conduct     1
# 205                         Institutions     1
# 206                      Being_obligated     1
# 207                 Intentionally_create     1
# 208                      Estimated_value     1
# 209                    Hostile_encounter     1
# 210                       Undergo_change     1
# 211                           Undressing     1
# 212                            Buildings     1
# 213                     Chemical_potency     1
# 214                       Being_relevant     1
# 215                             Reliance     1
# 216                Perception_experience     1
# 217                      Toxic_substance     1
# 218                                 Fame     1
# 219                    Coming_to_believe     1
# 220                                 Luck     1
# 221                             Building     1
# 222                            Attention     1
# 223             Cause_change_of_strength     1
# 224                         Representing     1
# 225              Rewards_and_punishments     1
# 226                            Dimension     1
# 227                       Accomplishment     1
# 228                           Body_parts     1
# 229                           Estimating     1
# 230                     Active_substance     1
# 231                      Performing_arts     1
# 232                        Relative_time     1
# 233                          Sufficiency     1
# 234                 Medical_intervention     1
# 235                        Reveal_secret     1
# 236                      Ordinal_numbers     1
# 237                                Event     1
# 238                             Scarcity     1
# 239                              Economy     1
# 240                               Hiring     1
# 241                    Building_subparts     1
# 242                            Posing_as     1
# 243                           Typicality     1
# 244                  Commutative_process     1
# 245                          Predicament     1
# 246                              Destiny     1
# 247                Evaluative_comparison     1
# 248                             Desiring     1
# 249                             Offering     1
# 250                              Verdict     1
# 251                 Duration_description     1

# %%
 getPlot(list_all,'PRED')
