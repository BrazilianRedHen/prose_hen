# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
pd.set_option('display.max_rows',None)

# %%
list_head
# Out:
#                       index  PRED
# 0                       Age    16
# 1              Taking_sides     6
# 2                      Goal     5
# 3                   Weather     5
# 4                  Exchange     5
# 5                  Evidence     3
# 6                 Aggregate     3
# 7                Estimating     2
# 8          Ingest_substance     2
# 9                   Pattern     2
# 10                Assessing     2
# 11                 Creating     2
# 12       Being_in_operation     2
# 13                    Gizmo     2
# 14             Identicality     2
# 15    Proportional_quantity     2
# 16           Calendric_unit     2
# 17     Distributed_position     1
# 18                Diversity     1
# 19          Biological_area     1
# 20                Direction     1
# 21             Social_event     1
# 22     Cognitive_connection     1
# 23        Political_locales     1
# 24            Collaboration     1
# 25               Protecting     1
# 26  Level_of_force_exertion     1
# 27            Accompaniment     1
# 28                   Locale     1
# 29             Cause_change     1
# 30               Capability     1
# 31     Temporal_collocation     1
# 32                Causation     1
# 33            Being_at_risk     1
# 34       Part_orientational     1
# 35        Building_subparts     1
# 36                   Plants     1
# 37                 Exemplar     1
# 38                 Removing     1
# 39       Medical_conditions     1
# 40                  Storing     1
# 41                  Filling     1
# 42   Agree_or_refuse_to_act     1
# 43    Commutative_statement     1
# 44        Locative_relation     1
# 45                 Instance     1
# 46                    Means     1
# 47          Being_in_effect     1
# 48              Temperature     1
# 49                   Origin     1
# 50      Commutative_process     1
# 51         Measure_duration     1

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                                    index  PRED
# 0                                    Age   151
# 1                                   Goal   122
# 2                            Temperature    49
# 3                       Measure_duration    49
# 4                           Taking_sides    45
# 5                              Aggregate    43
# 6                                 Degree    42
# 7             Change_position_on_a_scale    42
# 8                               Evidence    29
# 9                               Exchange    28
# 10                             Frequency    27
# 11                  Temporal_collocation    27
# 12                      Cardinal_numbers    22
# 13                           Contingency    22
# 14                       Quantified_mass    20
# 15                    Being_in_operation    20
# 16                    Medical_conditions    18
# 17                            Possession    18
# 18                                 Gizmo    18
# 19                        Calendric_unit    18
# 20                   Earnings_and_losses    17
# 21                           Suitability    17
# 22                                Fields    17
# 23                                Origin    17
# 24                      Ingest_substance    16
# 25                              Exemplar    16
# 26                                 Means    15
# 27                                 Store    15
# 28                     Building_subparts    14
# 29                       Being_in_effect    13
# 30                    Part_orientational    12
# 31                 Proportional_quantity    12
# 32                              Creating    12
# 33                     Political_locales    12
# 34                           Possibility    12
# 35                   Objective_influence    11
# 36                       Biological_area    11
# 37                             Increment    10
# 38                         Extreme_value    10
# 39                               Weather    10
# 40                        Measure_volume    10
# 41                              Quantity    10
# 42                               Kinship    10
# 43                           Time_vector    10
# 44                           Self_motion     9
# 45                Criminal_investigation     9
# 46                     Locative_relation     9
# 47                            Importance     9
# 48                              Research     8
# 49                            Membership     8
# 50                         Text_creation     8
# 51                        Coming_up_with     8
# 52                     Cause_to_perceive     7
# 53                       Cause_expansion     7
# 54                            Capability     7
# 55                               Placing     7
# 56                                Locale     7
# 57                              Negation     7
# 58                           Progression     7
# 59                           Obviousness     7
# 60                     Behind_the_scenes     7
# 61                          Cause_change     6
# 62                           Expectation     6
# 63                         Communication     6
# 64             Non-commutative_statement     6
# 65                              Response     6
# 66                               Filling     6
# 67                                  Food     5
# 68                   Transition_to_state     5
# 69                             Causation     5
# 70                          Identicality     5
# 71                         Accompaniment     5
# 72                             Direction     5
# 73                            Protecting     5
# 74                                 Event     5
# 75                         Being_at_risk     5
# 76              Cause_temperature_change     5
# 77                          Amounting_to     5
# 78   Cause_change_of_position_on_a_scale     5
# 79                       Being_necessary     5
# 80                         Sole_instance     5
# 81                                  Size     5
# 82                            First_rank     5
# 83                     Duration_relation     5
# 84                     Intentionally_act     5
# 85                       Experimentation     5
# 86            Condition_symptom_relation     5
# 87             Interior_profile_relation     5
# 88                 Evaluative_comparison     4
# 89                     Change_event_time     4
# 90                      Being_in_control     4
# 91                       Performing_arts     4
# 92                             Statement     4
# 93                      Part_inner_outer     4
# 94                      Natural_features     4
# 95                                Giving     4
# 96                  Performers_and_roles     4
# 97                             Dispersal     4
# 98                                Supply     4
# 99                            Estimating     4
# 100                            Assessing     3
# 101              Level_of_force_exertion     3
# 102                   Terms_of_agreement     3
# 103                  Information_display     3
# 104                              Pattern     3
# 105                     Process_continue     3
# 106                      Locale_by_event     3
# 107                    Assigned_location     3
# 108                             Scrutiny     3
# 109                           Stinginess     3
# 110                    Perception_active     3
# 111                      Estimated_value     3
# 112                         Be_subset_of     3
# 113                       Undergo_change     3
# 114                       Come_down_with     3
# 115                             Choosing     3
# 116                    System_complexity     3
# 117                               Plants     3
# 118                 Cognitive_connection     3
# 119                           Strictness     3
# 120                      Attempt_suasion     3
# 121                            Hindering     3
# 122                            Ground_up     3
# 123               Agree_or_refuse_to_act     2
# 124                                Using     2
# 125                  Cause_to_amalgamate     2
# 126                               Shapes     2
# 127           Continued_state_of_affairs     2
# 128        Directional_locative_relation     2
# 129                             Roadways     2
# 130                            Sensation     2
# 131                              Storing     2
# 132                                 Cure     2
# 133                        Locale_by_use     2
# 134                Perception_experience     2
# 135                          Taking_time     2
# 136                                  Law     2
# 137                 Processing_materials     2
# 138                              Project     2
# 139               Undergo_transformation     2
# 140                                Death     2
# 141                              Network     2
# 142                  Commutative_process     2
# 143                          Predicament     2
# 144                               Reason     2
# 145                      Desirable_event     2
# 146                           Likelihood     2
# 147                        Collaboration     2
# 148                    Speed_description     2
# 149                            Diversity     2
# 150                  Cause_to_make_noise     2
# 151                         Organization     2
# 152                           Inspecting     2
# 153            Be_in_agreement_on_action     2
# 154                      Operate_vehicle     2
# 155                           Partiality     2
# 156                        Expensiveness     2
# 157                 Explaining_the_facts     2
# 158                Change_event_duration     2
# 159                          Information     2
# 160                     Quitting_a_place     2
# 161          Prevent_or_allow_possession     2
# 162                           Usefulness     2
# 163                        Process_start     2
# 164                           Businesses     2
# 165                   Individual_history     1
# 166                           Conquering     1
# 167                        Reveal_secret     1
# 168                     Activity_ongoing     1
# 169                           Similarity     1
# 170                             Encoding     1
# 171                           Leadership     1
# 172                     Version_sequence     1
# 173                 Distributed_position     1
# 174                        Manufacturing     1
# 175                       Food_gathering     1
# 176                            Employing     1
# 177                          Intoxicants     1
# 178                   Temporal_subregion     1
# 179                              Opinion     1
# 180                              Sending     1
# 181                           Assistance     1
# 182                       Categorization     1
# 183                         Cause_motion     1
# 184                          Ingredients     1
# 185                             Building     1
# 186                        Relative_time     1
# 187                                Color     1
# 188                   Success_or_failure     1
# 189                            Substance     1
# 190                    Stage_of_progress     1
# 191           Communicate_categorization     1
# 192                    Indigenous_origin     1
# 193                                 Rite     1
# 194                   Ranked_expectation     1
# 195                     People_by_origin     1
# 196               Judgment_communication     1
# 197                    Location_of_light     1
# 198                           Surpassing     1
# 199                      Risky_situation     1
# 200                              Purpose     1
# 201                        Exemplariness     1
# 202                            Thwarting     1
# 203                              Verdict     1
# 204            Body_description_holistic     1
# 205                   People_by_vocation     1
# 206                           Path_shape     1
# 207                             Labeling     1
# 208                      Give_impression     1
# 209                           Candidness     1
# 210                            Being_dry     1
# 211                       Required_event     1
# 212                            Exporting     1
# 213                             Boundary     1
# 214                           Containers     1
# 215                Commutative_statement     1
# 216                            Attention     1
# 217                             Dynamism     1
# 218                  Social_desirability     1
# 219                 Duration_description     1
# 220             Having_or_lacking_access     1
# 221               Non-gradable_proximity     1
# 222                             Removing     1
# 223                              Needing     1
# 224                      Being_obligated     1
# 225                            Recording     1
# 226            Actually_occurring_entity     1
# 227                               People     1
# 228                          Correctness     1

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                                    index  PRED
# 0                                    Age   167
# 1                                   Goal   127
# 2                           Taking_sides    51
# 3                            Temperature    50
# 4                       Measure_duration    50
# 5                              Aggregate    46
# 6                                 Degree    42
# 7             Change_position_on_a_scale    42
# 8                               Exchange    33
# 9                               Evidence    32
# 10                  Temporal_collocation    28
# 11                             Frequency    27
# 12                      Cardinal_numbers    22
# 13                           Contingency    22
# 14                    Being_in_operation    22
# 15                                 Gizmo    20
# 16                       Quantified_mass    20
# 17                        Calendric_unit    20
# 18                    Medical_conditions    19
# 19                                Origin    18
# 20                            Possession    18
# 21                      Ingest_substance    18
# 22                              Exemplar    17
# 23                   Earnings_and_losses    17
# 24                           Suitability    17
# 25                                Fields    17
# 26                                 Means    16
# 27                               Weather    15
# 28                     Building_subparts    15
# 29                                 Store    15
# 30                              Creating    14
# 31                       Being_in_effect    14
# 32                 Proportional_quantity    14
# 33                     Political_locales    13
# 34                    Part_orientational    13
# 35                           Possibility    12
# 36                       Biological_area    12
# 37                   Objective_influence    11
# 38                             Increment    10
# 39                        Measure_volume    10
# 40                     Locative_relation    10
# 41                         Extreme_value    10
# 42                              Quantity    10
# 43                           Time_vector    10
# 44                               Kinship    10
# 45                Criminal_investigation     9
# 46                           Self_motion     9
# 47                            Importance     9
# 48                                Locale     8
# 49                              Research     8
# 50                            Capability     8
# 51                         Text_creation     8
# 52                            Membership     8
# 53                        Coming_up_with     8
# 54                     Cause_to_perceive     7
# 55                           Obviousness     7
# 56                               Filling     7
# 57                     Behind_the_scenes     7
# 58                           Progression     7
# 59                          Cause_change     7
# 60                              Negation     7
# 61                               Placing     7
# 62                          Identicality     7
# 63                       Cause_expansion     7
# 64                             Direction     6
# 65                            Protecting     6
# 66                             Causation     6
# 67                            Estimating     6
# 68                         Accompaniment     6
# 69                         Being_at_risk     6
# 70             Non-commutative_statement     6
# 71                         Communication     6
# 72                              Response     6
# 73                           Expectation     6
# 74                         Sole_instance     5
# 75                             Assessing     5
# 76              Cause_temperature_change     5
# 77                       Experimentation     5
# 78                   Transition_to_state     5
# 79                                  Food     5
# 80                               Pattern     5
# 81                            First_rank     5
# 82                       Being_necessary     5
# 83   Cause_change_of_position_on_a_scale     5
# 84                                 Event     5
# 85                     Intentionally_act     5
# 86                                  Size     5
# 87             Interior_profile_relation     5
# 88                     Duration_relation     5
# 89            Condition_symptom_relation     5
# 90                          Amounting_to     5
# 91               Level_of_force_exertion     4
# 92                 Evaluative_comparison     4
# 93                      Being_in_control     4
# 94                      Part_inner_outer     4
# 95                       Performing_arts     4
# 96                             Statement     4
# 97                     Change_event_time     4
# 98                                Plants     4
# 99                      Natural_features     4
# 100                            Dispersal     4
# 101                               Giving     4
# 102                               Supply     4
# 103                 Performers_and_roles     4
# 104                 Cognitive_connection     4
# 105                   Terms_of_agreement     3
# 106                    Assigned_location     3
# 107                      Locale_by_event     3
# 108                           Stinginess     3
# 109                     Process_continue     3
# 110                  Information_display     3
# 111               Agree_or_refuse_to_act     3
# 112                        Collaboration     3
# 113                    Perception_active     3
# 114                             Choosing     3
# 115                       Come_down_with     3
# 116                       Undergo_change     3
# 117                            Ground_up     3
# 118                      Attempt_suasion     3
# 119                           Strictness     3
# 120                            Diversity     3
# 121                         Be_subset_of     3
# 122                      Estimated_value     3
# 123                  Commutative_process     3
# 124                            Hindering     3
# 125                    System_complexity     3
# 126                              Storing     3
# 127                             Scrutiny     3
# 128                                  Law     2
# 129                               Reason     2
# 130                          Taking_time     2
# 131               Undergo_transformation     2
# 132                        Locale_by_use     2
# 133                            Sensation     2
# 134                             Roadways     2
# 135                              Network     2
# 136                                Death     2
# 137                           Businesses     2
# 138                 Processing_materials     2
# 139                           Likelihood     2
# 140                          Predicament     2
# 141                              Project     2
# 142                             Removing     2
# 143                                 Cure     2
# 144                               Shapes     2
# 145                  Cause_to_amalgamate     2
# 146           Continued_state_of_affairs     2
# 147          Prevent_or_allow_possession     2
# 148                          Information     2
# 149                           Inspecting     2
# 150                  Cause_to_make_noise     2
# 151                 Explaining_the_facts     2
# 152                 Distributed_position     2
# 153                           Usefulness     2
# 154                Perception_experience     2
# 155                Commutative_statement     2
# 156                                Using     2
# 157                        Expensiveness     2
# 158                        Process_start     2
# 159                      Desirable_event     2
# 160                     Quitting_a_place     2
# 161        Directional_locative_relation     2
# 162                      Operate_vehicle     2
# 163                           Partiality     2
# 164                Change_event_duration     2
# 165            Be_in_agreement_on_action     2
# 166                         Organization     2
# 167                    Speed_description     2
# 168                      Risky_situation     1
# 169                           Conquering     1
# 170                         Cause_motion     1
# 171                          Ingredients     1
# 172                       Categorization     1
# 173                           Surpassing     1
# 174                             Building     1
# 175                                Color     1
# 176                           Assistance     1
# 177                              Purpose     1
# 178                        Relative_time     1
# 179                            Thwarting     1
# 180                        Exemplariness     1
# 181                       Food_gathering     1
# 182                           Leadership     1
# 183                             Encoding     1
# 184                           Similarity     1
# 185                     Activity_ongoing     1
# 186                   Individual_history     1
# 187                     Version_sequence     1
# 188                          Intoxicants     1
# 189                   People_by_vocation     1
# 190            Body_description_holistic     1
# 191                           Containers     1
# 192                           Path_shape     1
# 193                              Opinion     1
# 194                              Sending     1
# 195                   Temporal_subregion     1
# 196                    Location_of_light     1
# 197                     People_by_origin     1
# 198               Judgment_communication     1
# 199                            Being_dry     1
# 200                 Duration_description     1
# 201                       Required_event     1
# 202                              Needing     1
# 203                               People     1
# 204             Having_or_lacking_access     1
# 205                      Being_obligated     1
# 206                            Recording     1
# 207                             Instance     1
# 208                             Dynamism     1
# 209                  Social_desirability     1
# 210            Actually_occurring_entity     1
# 211                            Attention     1
# 212                   Success_or_failure     1
# 213                             Labeling     1
# 214                            Exporting     1
# 215                        Manufacturing     1
# 216                           Candidness     1
# 217                             Boundary     1
# 218                    Stage_of_progress     1
# 219           Communicate_categorization     1
# 220                            Substance     1
# 221                    Indigenous_origin     1
# 222                                 Rite     1
# 223                         Social_event     1
# 224                      Give_impression     1
# 225                              Verdict     1
# 226                        Reveal_secret     1
# 227                   Ranked_expectation     1
# 228               Non-gradable_proximity     1
# 229                            Employing     1
# 230                          Correctness     1

# %%
 getPlot(list_all,'PRED')
