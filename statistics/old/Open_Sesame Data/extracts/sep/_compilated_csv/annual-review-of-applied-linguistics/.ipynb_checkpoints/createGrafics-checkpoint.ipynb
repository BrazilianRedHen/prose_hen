# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
pd.set_option('display.max_rows',None)

# %%
list_head
# Out:
#                     index  PRED
# 0                    Goal     8
# 1                     Age     7
# 2            Identicality     5
# 3      Education_teaching     5
# 4                Research     3
# 5            Taking_sides     3
# 6              Possession     3
# 7        Ingest_substance     2
# 8     Operational_testing     2
# 9       Intentionally_act     2
# 10               Building     2
# 11              Aggregate     2
# 12                 People     2
# 13                  Means     2
# 14       Point_of_dispute     2
# 15            Time_vector     1
# 16          Participation     1
# 17                Kinship     1
# 18  Proportional_quantity     1
# 19            Progression     1
# 20              Defending     1
# 21         Becoming_aware     1
# 22     Being_in_operation     1
# 23             Assistance     1
# 24              Frequency     1
# 25    Expressing_publicly     1
# 26       Measure_duration     1
# 27              Existence     1
# 28              Assessing     1
# 29                 Fields     1
# 30             Typicality     1
# 31   Performers_and_roles     1
# 32       Process_continue     1
# 33            Information     1
# 34       Cardinal_numbers     1
# 35   Processing_materials     1
# 36      Building_subparts     1
# 37        Performing_arts     1
# 38        Quantified_mass     1
# 39   Temporal_collocation     1
# 40        Being_obligated     1
# 41      Political_locales     1
# 42    Cause_to_make_noise     1
# 43               Scrutiny     1
# 44        Experiencer_obj     1

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                              index  PRED
# 0                              Age    94
# 1                             Goal    59
# 2                     Identicality    48
# 3                           Degree    40
# 4               Education_teaching    32
# 5                         Research    31
# 6                  Being_obligated    27
# 7                       Possession    25
# 8                     Taking_sides    21
# 9                 Cardinal_numbers    19
# 10              Being_in_operation    17
# 11            Temporal_collocation    17
# 12                Measure_duration    15
# 13                       Increment    14
# 14                        Evidence    13
# 15                           Means    12
# 16               Locative_relation    12
# 17                Point_of_dispute    10
# 18            Performers_and_roles    10
# 19               Political_locales    10
# 20                      Importance    10
# 21           Proportional_quantity    10
# 22            Processing_materials     9
# 23                       Aggregate     9
# 24              Medical_conditions     9
# 25                        Scrutiny     9
# 26                 Quantified_mass     9
# 27                       Documents     8
# 28                             Law     8
# 29                          Custom     8
# 30                        Exchange     7
# 31                     Time_vector     7
# 32                   Accompaniment     7
# 33                Ingest_substance     7
# 34               Intentionally_act     7
# 35               Building_subparts     6
# 36                 Performing_arts     6
# 37                        Negation     6
# 38                       Assessing     6
# 39                          People     6
# 40                           Gizmo     6
# 41              People_by_vocation     6
# 42                    Organization     6
# 43                           Topic     6
# 44       Interior_profile_relation     6
# 45                   Sole_instance     5
# 46                        Building     5
# 47                 Being_in_effect     5
# 48             Operational_testing     5
# 49         Level_of_force_exertion     5
# 50                         Control     5
# 51      Change_position_on_a_scale     5
# 52                    Be_subset_of     5
# 53                       Frequency     5
# 54                   Relative_time     5
# 55                       Awareness     5
# 56                       Receiving     5
# 57                      Discussion     5
# 58                        Offering     4
# 59                       Attention     4
# 60                         Needing     4
# 61                          Supply     4
# 62            Cognitive_connection     4
# 63                        Instance     4
# 64                    Execute_plan     4
# 65                        Exemplar     4
# 66                  Becoming_aware     4
# 67                   Text_creation     4
# 68             Expressing_publicly     4
# 69                         Funding     3
# 70                Natural_features     3
# 71                      Body_parts     3
# 72                     Ingredients     3
# 73                      Stinginess     3
# 74                     Suitability     3
# 75            Intentionally_create     3
# 76                     Summarizing     3
# 77                          Fields     3
# 78                 Activity_finish     3
# 79                     Predicament     3
# 80                  Coming_up_with     3
# 81                  Categorization     3
# 82               Successful_action     3
# 83                          Origin     3
# 84            Explaining_the_facts     3
# 85                People_by_origin     3
# 86                      Leadership     3
# 87     Foreign_or_domestic_country     3
# 88                      Cogitation     3
# 89                       Deserving     3
# 90       Biological_classification     3
# 91                 Experiencer_obj     2
# 92                 Resolve_problem     2
# 93                       Diversity     2
# 94                     Obviousness     2
# 95             Earnings_and_losses     2
# 96                 Cause_expansion     2
# 97                     Self_motion     2
# 98                       Causation     2
# 99                   Dead_or_alive     2
# 100                 Undergo_change     2
# 101                        Pattern     2
# 102                       Presence     2
# 103                Attempt_suasion     2
# 104            Objective_influence     2
# 105                     First_rank     2
# 106                  Communication     2
# 107                    Possibility     2
# 108                 Required_event     2
# 109                     Part_whole     2
# 110      Body_description_holistic     2
# 111      Non-commutative_statement     2
# 112                 Precariousness     2
# 113                       Boundary     2
# 114     Condition_symptom_relation     2
# 115                      Statement     2
# 116                           Text     2
# 117                     Quarreling     2
# 118                  Process_start     2
# 119                      Buildings     2
# 120                 Measure_volume     2
# 121      Level_of_force_resistance     2
# 122                Being_necessary     2
# 123                 Calendric_unit     2
# 124                     Inspecting     2
# 125                        Project     2
# 126                           Size     2
# 127                      Attaching     2
# 128                       Bringing     2
# 129         Judgment_communication     2
# 130                       Creating     2
# 131                      Direction     2
# 132              Duration_relation     1
# 133                        Kinship     1
# 134                    Progression     1
# 135                    Contingency     1
# 136                          Craft     1
# 137                    Emphasizing     1
# 138              Experiencer_focus     1
# 139         Contrary_circumstances     1
# 140            Social_desirability     1
# 141                        Opinion     1
# 142        Rewards_and_punishments     1
# 143                  Locale_by_use     1
# 144                     Compliance     1
# 145                Claim_ownership     1
# 146     Continued_state_of_affairs     1
# 147            Commutative_process     1
# 148                      Timetable     1
# 149                     Businesses     1
# 150                        Verdict     1
# 151      Make_cognitive_connection     1
# 152                       Response     1
# 153                Desirable_event     1
# 154                  Legal_rulings     1
# 155              Cause_to_perceive     1
# 156           Cause_to_be_included     1
# 157                    Sufficiency     1
# 158                       Adducing     1
# 159                Locale_by_event     1
# 160                     Similarity     1
# 161                     Partiality     1
# 162                      Besieging     1
# 163            Specific_individual     1
# 164             Ranked_expectation     1
# 165                     Cause_harm     1
# 166  Social_interaction_evaluation     1
# 167                      Residence     1
# 168      Be_in_agreement_on_action     1
# 169                         Giving     1
# 170                   Social_event     1
# 171                        Seeking     1
# 172                       Relation     1
# 173            Have_as_requirement     1
# 174                          Event     1
# 175                     Membership     1
# 176       Having_or_lacking_access     1
# 177                         Aiming     1
# 178                        Attempt     1
# 179                        Placing     1
# 180               Active_substance     1
# 181     Communicate_categorization     1
# 182                       Quantity     1
# 183                       Legality     1
# 184                      Attending     1
# 185                Body_decoration     1
# 186           Subjective_influence     1
# 187                      Employing     1
# 188                   Ride_vehicle     1
# 189                   Amounting_to     1
# 190                   Cause_motion     1
# 191                     Publishing     1
# 192                Ordinal_numbers     1
# 193             Success_or_failure     1
# 194                       Labeling     1

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                              index  PRED
# 0                              Age   101
# 1                             Goal    67
# 2                     Identicality    53
# 3                           Degree    40
# 4               Education_teaching    37
# 5                         Research    34
# 6                       Possession    28
# 7                  Being_obligated    28
# 8                     Taking_sides    24
# 9                 Cardinal_numbers    20
# 10              Being_in_operation    18
# 11            Temporal_collocation    18
# 12                Measure_duration    16
# 13                       Increment    14
# 14                           Means    14
# 15                        Evidence    13
# 16               Locative_relation    12
# 17                Point_of_dispute    12
# 18                       Aggregate    11
# 19               Political_locales    11
# 20            Performers_and_roles    11
# 21           Proportional_quantity    11
# 22                      Importance    10
# 23            Processing_materials    10
# 24                 Quantified_mass    10
# 25                        Scrutiny    10
# 26               Intentionally_act     9
# 27                Ingest_substance     9
# 28              Medical_conditions     9
# 29                             Law     8
# 30                     Time_vector     8
# 31                       Documents     8
# 32                          People     8
# 33                          Custom     8
# 34                        Building     7
# 35                 Performing_arts     7
# 36                   Accompaniment     7
# 37               Building_subparts     7
# 38             Operational_testing     7
# 39                        Exchange     7
# 40                       Assessing     7
# 41                           Topic     6
# 42                       Frequency     6
# 43                        Negation     6
# 44                    Organization     6
# 45                           Gizmo     6
# 46              People_by_vocation     6
# 47       Interior_profile_relation     6
# 48                    Be_subset_of     5
# 49         Level_of_force_exertion     5
# 50                 Being_in_effect     5
# 51                  Becoming_aware     5
# 52                         Control     5
# 53      Change_position_on_a_scale     5
# 54                   Sole_instance     5
# 55                   Relative_time     5
# 56             Expressing_publicly     5
# 57                      Discussion     5
# 58                       Awareness     5
# 59                       Receiving     5
# 60                       Attention     4
# 61                          Supply     4
# 62                          Fields     4
# 63                        Offering     4
# 64                        Exemplar     4
# 65                         Needing     4
# 66                        Instance     4
# 67                    Execute_plan     4
# 68            Cognitive_connection     4
# 69                   Text_creation     4
# 70                 Experiencer_obj     3
# 71                Natural_features     3
# 72                      Leadership     3
# 73                         Funding     3
# 74                     Summarizing     3
# 75            Intentionally_create     3
# 76                     Suitability     3
# 77                      Stinginess     3
# 78                People_by_origin     3
# 79                     Ingredients     3
# 80                 Activity_finish     3
# 81                     Predicament     3
# 82                      Body_parts     3
# 83                  Categorization     3
# 84                  Coming_up_with     3
# 85            Explaining_the_facts     3
# 86                          Origin     3
# 87               Successful_action     3
# 88       Biological_classification     3
# 89                      Cogitation     3
# 90                       Deserving     3
# 91     Foreign_or_domestic_country     3
# 92                        Bringing     2
# 93                        Creating     2
# 94             Objective_influence     2
# 95                 Attempt_suasion     2
# 96          Judgment_communication     2
# 97                     Self_motion     2
# 98                  Undergo_change     2
# 99                      Quarreling     2
# 100                      Causation     2
# 101                        Project     2
# 102                  Communication     2
# 103                     Part_whole     2
# 104                      Statement     2
# 105                       Boundary     2
# 106                  Dead_or_alive     2
# 107                Resolve_problem     2
# 108      Non-commutative_statement     2
# 109                 Precariousness     2
# 110                        Pattern     2
# 111     Condition_symptom_relation     2
# 112            Earnings_and_losses     2
# 113                Cause_expansion     2
# 114                    Progression     2
# 115      Body_description_holistic     2
# 116                      Diversity     2
# 117                 Required_event     2
# 118                     First_rank     2
# 119                    Obviousness     2
# 120                        Kinship     2
# 121                 Measure_volume     2
# 122                      Attaching     2
# 123                           Text     2
# 124                     Inspecting     2
# 125                 Calendric_unit     2
# 126                           Size     2
# 127      Level_of_force_resistance     2
# 128                      Direction     2
# 129                  Process_start     2
# 130                    Possibility     2
# 131                       Presence     2
# 132                      Buildings     2
# 133                Being_necessary     2
# 134                       Response     1
# 135               Process_continue     1
# 136                      Besieging     1
# 137                     Businesses     1
# 138                      Timetable     1
# 139                Claim_ownership     1
# 140              Experiencer_focus     1
# 141                      Existence     1
# 142                     Compliance     1
# 143         Contrary_circumstances     1
# 144                     Assistance     1
# 145                  Participation     1
# 146                     Publishing     1
# 147                        Verdict     1
# 148                   Ride_vehicle     1
# 149            Social_desirability     1
# 150                  Legal_rulings     1
# 151                      Attending     1
# 152        Rewards_and_punishments     1
# 153                      Defending     1
# 154                        Opinion     1
# 155               Active_substance     1
# 156              Cause_to_perceive     1
# 157                          Craft     1
# 158              Duration_relation     1
# 159           Cause_to_be_included     1
# 160      Make_cognitive_connection     1
# 161                  Locale_by_use     1
# 162            Commutative_process     1
# 163     Continued_state_of_affairs     1
# 164                       Quantity     1
# 165                     Membership     1
# 166                    Contingency     1
# 167  Social_interaction_evaluation     1
# 168                Body_decoration     1
# 169            Cause_to_make_noise     1
# 170            Specific_individual     1
# 171                      Employing     1
# 172                     Similarity     1
# 173                     Partiality     1
# 174                   Amounting_to     1
# 175                   Cause_motion     1
# 176                Locale_by_event     1
# 177                       Adducing     1
# 178                Ordinal_numbers     1
# 179             Success_or_failure     1
# 180           Subjective_influence     1
# 181                    Sufficiency     1
# 182                          Event     1
# 183                         Aiming     1
# 184                      Residence     1
# 185                       Relation     1
# 186      Be_in_agreement_on_action     1
# 187       Having_or_lacking_access     1
# 188                Desirable_event     1
# 189                    Information     1
# 190                     Cause_harm     1
# 191             Ranked_expectation     1
# 192                    Emphasizing     1
# 193                        Seeking     1
# 194                     Typicality     1
# 195                        Attempt     1
# 196                        Placing     1
# 197                   Social_event     1
# 198                       Labeling     1
# 199     Communicate_categorization     1
# 200                         Giving     1
# 201                       Legality     1
# 202            Have_as_requirement     1

# %%
 getPlot(list_all,'PRED')
