# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                            index  PRED
# 0                            Age   123
# 1                           Goal    92
# 2                   Taking_sides    57
# 3                          Gizmo    38
# 4                         Degree    36
# 5                        Network    30
# 6                       Choosing    23
# 7        Level_of_force_exertion    22
# 8                    Information    21
# 9                         Fields    21
# 10          Temporal_collocation    21
# 11                      Evidence    20
# 12                    Businesses    20
# 13                      Dynamism    19
# 14                          Size    18
# 15               Performing_arts    18
# 16                Measure_volume    17
# 17              Ingest_substance    15
# 18           Earnings_and_losses    14
# 19              Cardinal_numbers    14
# 20                       Project    14
# 21              Natural_features    13
# 22             Building_subparts    13
# 23                         Means    12
# 24                 Accompaniment    11
# 25            Being_in_operation    11
# 26                  Be_subset_of    11
# 27             Assigned_location    11
# 28                   Time_vector    11
# 29               Quantified_mass    10
# ..                           ...   ...
# 190                    Sharpness     1
# 191          Thermodynamic_phase     1
# 192                   Separating     1
# 193                 Organization     1
# 194               Becoming_aware     1
# 195                  Commonality     1
# 196                        Craft     1
# 197              State_of_entity     1
# 198                    Documents     1
# 199  Prevent_or_allow_possession     1
# 200             Process_continue     1
# 201                        Topic     1
# 202           Motion_directional     1
# 203                   Stinginess     1
# 204            Social_connection     1
# 205             Being_in_control     1
# 206   Subordinates_and_superiors     1
# 207                     Removing     1
# 208                         Type     1
# 209         Subjective_influence     1
# 210              Ordinal_numbers     1
# 211                     Deciding     1
# 212  Emotions_of_mental_activity     1
# 213            Perception_active     1
# 214               Event_instance     1
# 215                        Death     1
# 216                     Arriving     1
# 217                   Limitation     1
# 218                   Usefulness     1
# 219                   Commitment     1
#
# [220 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
