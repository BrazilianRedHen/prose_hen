# %%
import numpy as np
import pandas as pd
import glob
import os
#import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_all
# Out:
#                      index  PRED
# 0                      Age   142
# 1                     Goal   112
# 2             Taking_sides    57
# 3                    Means    53
# 4       Being_in_operation    41
# 5                Sensation    35
# 6                   Degree    32
# 7         Ingest_substance    28
# 8                 Evidence    27
# 9                  Network    26
# 10               Aggregate    24
# 11        Cardinal_numbers    20
# 12               Increment    18
# 13              Possession    18
# 14    Temporal_collocation    17
# 15                 Vehicle    17
# 16         Quantified_mass    16
# 17                    Size    16
# 18      Medical_conditions    15
# 19    Performers_and_roles    15
# 20        Measure_duration    15
# 21                   Gizmo    14
# 22             Information    14
# 23   Measurable_attributes    14
# 24         Performing_arts    14
# 25              Businesses    13
# 26            Identicality    13
# 27           Accompaniment    13
# 28                Scrutiny    12
# 29      Education_teaching    11
# ..                     ...   ...
# 197   Medical_intervention     1
# 198    Respond_to_proposal     1
# 199               Roadways     1
# 200              Execution     1
# 201             Similarity     1
# 202    Cause_to_amalgamate     1
# 203    Specific_individual     1
# 204                Sending     1
# 205   Cognitive_connection     1
# 206      Successful_action     1
# 207         Stimulus_focus     1
# 208                Conduct     1
# 209               Artifact     1
# 210   Degree_of_processing     1
# 211      Stage_of_progress     1
# 212     Terms_of_agreement     1
# 213      Social_connection     1
# 214               Boundary     1
# 215    Thermodynamic_phase     1
# 216              Dispersal     1
# 217                Placing     1
# 218               Creating     1
# 219    Objective_influence     1
# 220        Spatial_contact     1
# 221                Attempt     1
# 222               Exchange     1
# 223             Typicality     1
# 224          Reveal_secret     1
# 225                    Law     1
# 226               Clothing     1
#
# [227 rows x 2 columns]

# %%
allFileName = "..\\excel\\"+os.path.basename(dirpath)+"_all.xls"
list_all.to_excel(allFileName, index = None, header=True)

# %%
 #getPlot(list_head,'PRED')

# %%
 #getPlot(list_content,'PRED')

# %%
 #getPlot(list_all,'PRED')
