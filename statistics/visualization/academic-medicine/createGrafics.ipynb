# %%
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dirpath = os.getcwd()
folder = os.path.basename(dirpath)

# %%
df_all = pd.read_csv(folder+"_all.csv")
df_head = pd.read_csv(folder+"_head.csv")
df_content = pd.read_csv(folder+"_content.csv")

# %%
def getListCount(df,title):
    listOfterms = df[title].value_counts()
    return listOfterms

# %%
list_all = getListCount(df_all,'PRED')[1:].to_frame().reset_index()
list_head = getListCount(df_head,'PRED')[1:].to_frame().reset_index()
list_content = getListCount(df_content,'PRED')[1:].to_frame().reset_index()

# %%
def getPlot(df,label):
    sns.set(style="whitegrid")
    plt.figure(figsize=(23, 6))
    plt.xticks(rotation=70)
    ax = sns.barplot(x="index", y=label, data=df)

# %%
list_head
# Out:
#                    index  PRED
# 0                    Age    14
# 1           Taking_sides     9
# 2     Education_teaching     8
# 3                   Goal     6
# 4      Building_subparts     3
# 5              Assessing     3
# 6       Cardinal_numbers     2
# 7          Accompaniment     2
# 8               Evidence     2
# 9     Being_in_operation     2
# 10          Institutions     2
# 11          Be_subset_of     2
# 12            Possession     2
# 13                Origin     1
# 14     Locative_relation     1
# 15           Obviousness     1
# 16           Self_motion     1
# 17           Time_vector     1
# 18           Ingredients     1
# 19            Importance     1
# 20       Body_decoration     1
# 21          Identicality     1
# 22              Instance     1
# 23    Medical_conditions     1
# 24       Being_in_effect     1
# 25   Medical_specialties     1
# 26              Creating     1
# 27  Duration_description     1
# 28      Ingest_substance     1
# 29              Research     1

# %%
 getPlot(list_head,'PRED')

# %%
list_content
# Out:
#                            index  PRED
# 0                            Age   149
# 1                           Goal   108
# 2             Education_teaching    62
# 3                   Taking_sides    49
# 4                         Degree    31
# 5                         People    26
# 6                          Gizmo    26
# 7                      Assessing    23
# 8                Quantified_mass    22
# 9                   Identicality    22
# 10                      Evidence    20
# 11                         Means    20
# 12                      Desiring    19
# 13                    Possession    19
# 14            Being_in_operation    19
# 15              Ingest_substance    18
# 16             Intentionally_act    18
# 17            Medical_conditions    16
# 18                 Accompaniment    15
# 19                      Research    15
# 20            People_by_vocation    15
# 21          Temporal_collocation    15
# 22                Measure_volume    14
# 23              Cardinal_numbers    13
# 24              Measure_duration    13
# 25                     Statement    13
# 26                      Scrutiny    13
# 27                     Causation    13
# 28                     Aggregate    13
# 29                   Possibility    13
# ..                           ...   ...
# 225              Ordinal_numbers     1
# 226                        Craft     1
# 227                  Information     1
# 228               Being_relevant     1
# 229                   Membership     1
# 230          Position_on_a_scale     1
# 231                  Obviousness     1
# 232                       Domain     1
# 233                         Luck     1
# 234              Mental_property     1
# 235                 Simultaneity     1
# 236                    Dispersal     1
# 237                      Vehicle     1
# 238      Level_of_force_exertion     1
# 239              Resolve_problem     1
# 240                      Weather     1
# 241                    Replacing     1
# 242                    Attaching     1
# 243                  Sufficiency     1
# 244                     Relation     1
# 245                Expensiveness     1
# 246                 Coming_to_be     1
# 247                    Receiving     1
# 248                  Occupy_rank     1
# 249                      Request     1
# 250              Differentiation     1
# 251                    Awareness     1
# 252                       Reason     1
# 253  Relational_natural_features     1
# 254                    Attention     1
#
# [255 rows x 2 columns]

# %%
 getPlot(list_content,'PRED')

# %%
list_all
# Out:
#                            index  PRED
# 0                            Age   163
# 1                           Goal   114
# 2             Education_teaching    70
# 3                   Taking_sides    58
# 4                         Degree    31
# 5                      Assessing    26
# 6                         People    26
# 7                          Gizmo    26
# 8                   Identicality    23
# 9                Quantified_mass    22
# 10                      Evidence    22
# 11                    Possession    21
# 12            Being_in_operation    21
# 13                         Means    20
# 14                      Desiring    19
# 15              Ingest_substance    19
# 16             Intentionally_act    18
# 17                 Accompaniment    17
# 18            Medical_conditions    17
# 19                      Research    16
# 20          Temporal_collocation    15
# 21              Cardinal_numbers    15
# 22            People_by_vocation    15
# 23                Measure_volume    14
# 24                      Creating    13
# 25                      Scrutiny    13
# 26                     Statement    13
# 27              Measure_duration    13
# 28             Building_subparts    13
# 29                     Causation    13
# ..                           ...   ...
# 225              Resolve_problem     1
# 226                        Craft     1
# 227                  Information     1
# 228               Being_relevant     1
# 229                   Membership     1
# 230          Position_on_a_scale     1
# 231                       Domain     1
# 232                         Luck     1
# 233              Mental_property     1
# 234                 Simultaneity     1
# 235                    Dispersal     1
# 236                      Vehicle     1
# 237      Level_of_force_exertion     1
# 238              Ordinal_numbers     1
# 239                    Replacing     1
# 240                    Recording     1
# 241                    Attaching     1
# 242                 Desirability     1
# 243                     Relation     1
# 244                Expensiveness     1
# 245                 Coming_to_be     1
# 246                    Receiving     1
# 247                  Occupy_rank     1
# 248                      Request     1
# 249              Differentiation     1
# 250                    Awareness     1
# 251                       Reason     1
# 252  Relational_natural_features     1
# 253                      Weather     1
# 254                    Attention     1
#
# [255 rows x 2 columns]

# %%
 getPlot(list_all,'PRED')
